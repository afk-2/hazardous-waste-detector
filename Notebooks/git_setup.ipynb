# %%
# Git Setup for Hazardous Waste Detector Project
# This notebook will initialize the Git repository and push the project to GitHub.

# %%
# %cd "drive/My Drive/Colab Notebooks/Waste Classification Project"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/Waste Classification Project'
# /content/drive/My Drive/Colab Notebooks/Waste Classification Project

# %%
# !git init
# !git branch -M main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/Waste Classification Project/.git/

# %%
# !git branch -m main

# %%
# !git config --global user.email "abdurahman.khan@gmail.com"
# !git config --global user.name "afk-2"

# %%
# !git reset --soft HEAD~1

# %%
# !git commit --amend --no-edit
# Out:
# [main 11d3077] Initial commit - Creating Project and Git Setup
#  Date: Sun Feb 16 15:28:06 2025 +0000
#  2 files changed, 2 insertions(+)
#  create mode 100644 Notebooks/dataset_prep.ipynb
#  create mode 100644 Notebooks/git_setup.ipynb

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 1.76 KiB | 119.00 KiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/afk-2/hazardous-waste-detector.git
#  * [new branch]      main -> main

# %%
# %cd "drive/MyDrive/Colab Notebooks/Waste Classification Project"
# Out:
# [Errno 2] No such file or directory: 'Waste Classification Project'
# /content/drive/My Drive/Colab Notebooks/Waste Classification Project
